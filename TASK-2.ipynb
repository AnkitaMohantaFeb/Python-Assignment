# %% [markdown]
# ## 1

# %% [markdown]
# Install vim and execute a hello world script using powershell
#
# Python installation link - https://youtu.be/M5ILgNI0iXw (first 20 minutes)
#
# Vim Installation link - https://youtu.be/SBOFnzVuzOE
#
#     'Done'

# %% [markdown]
# ## 2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
height=np.random.normal(140,20,1000)

# %%
plt.figure(dpi=200)

# %%
plt.title("Height Distribution")
# Out:
# Text(0.5, 1.0, 'Height Distribution')

# %%
("Height(cm)")
# Out:
# Text(0.5, 0, 'Height(cm)')

# %%
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(height,bins=30,ec="gold")
# Out:
# (array([ 1.,  1.,  5.,  7., 11., 12., 15., 21., 48., 43., 53., 67., 65.,
#         72., 89., 89., 69., 76., 57., 55., 35., 36., 28., 18., 10.,  8.,
#          5.,  1.,  0.,  3.]),
#  array([ 79.8791624 ,  83.98459511,  88.09002781,  92.19546051,
#          96.30089322, 100.40632592, 104.51175862, 108.61719133,
#         112.72262403, 116.82805673, 120.93348944, 125.03892214,
#         129.14435484, 133.24978755, 137.35522025, 141.46065295,
#         145.56608565, 149.67151836, 153.77695106, 157.88238376,
#         161.98781647, 166.09324917, 170.19868187, 174.30411458,
#         178.40954728, 182.51497998, 186.62041269, 190.72584539,
#         194.83127809, 198.9367108 , 203.0421435 ]),
#  <BarContainer object of 30 artists>)

# %%
plt.show()

# %% [markdown]
# ## 3

# %% [markdown]
# In coding with Notepad is great for beginners, because you have no access to syntax highlighting, formatting, and other such automated features.
#
# Without these aides, you'll learn attention to detail, perseverance, resilience, and how to format your code yourself
# But it will be a lenthy process to know the correct syntax/ compile error compare to Jupyter Notebook.
#
# Jupyter notebook integrates code and its output into a single document that combines visualizations, narrative text, mathematical equations, and other rich media. In other words: it's a single document where you can run code, display the output, and also add explanations, formulas, charts, and make your work more transparent, understandable, repeatable, and shareable.

# %% [markdown]
# ## 4

# %% [markdown]
# Compiler considers the entire program as a whole and translates the entire source code in one run whereas Interpreter translates the source code line by line.

# %% [markdown]
# ## 5

# %% [markdown]
# Data structure is collection of data values and relationships between them.
# We need them to organize,manage and store data efficiently.
